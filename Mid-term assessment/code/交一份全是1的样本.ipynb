# %%
import pandas as pd

# %%
data = pd.read_csv('../data/test/test1.csv')

# %%
data.head(10)
# Out:
#       id_num program_type program_id  program_duration  test_id test_type  \
# 0   1442_124            Y        Y_4             121.0    124.0    online
# 1   12373_38            T        T_2             117.0     38.0       NaN
# 2   12035_21            T        T_3             134.0     21.0   offline
# 3   11148_86            V        V_3             131.0     86.0   offline
# 4   1362_131            Y        Y_3             135.0    131.0    online
# 5   4596_125            Y        Y_3             135.0    125.0   offline
# 6   9475_130            Y        Y_3             135.0    130.0    online
# 7   19270_93            V        V_2             121.0     93.0   offline
# 8   16699_47            T        T_1             131.0     47.0   offline
# 9  14930_155            Y        Y_1             136.0    155.0    online
#
#   difficulty_level  trainee_id gender            education  city_tier   age  \
# 0             easy      1442.0      M                  NaN        2.0   NaN
# ...

# %%
submission = data.copy()

# %%
submission
# Out:
#           id_num program_type program_id  program_duration  test_id test_type  \
# 0       1442_124            Y        Y_4             121.0    124.0    online
# 1       12373_38            T        T_2             117.0     38.0       NaN
# 2       12035_21            T        T_3             134.0     21.0   offline
# 3       11148_86            V        V_3             131.0     86.0   offline
# 4       1362_131            Y        Y_3             135.0    131.0    online
# ...          ...          ...        ...               ...      ...       ...
# 11679   3882_161            Z        Z_3             130.0    161.0   offline
# 11680    3426_38            T        T_2             117.0     38.0    online
# 11681  13063_142            Y        Y_2             120.0    142.0    online
# 11682    5667_82            V        V_3             131.0     82.0   offline
# 11683   4467_119            Y        Y_4             121.0      NaN    online
#
# ...

# %%
new = submission.loc[:,['id_num','is_pass']]
new
# Out:
#           id_num  is_pass
# 0       1442_124      NaN
# 1       12373_38      NaN
# 2       12035_21      NaN
# 3       11148_86      NaN
# 4       1362_131      NaN
# ...          ...      ...
# 11679   3882_161      NaN
# 11680    3426_38      NaN
# 11681  13063_142      NaN
# 11682    5667_82      NaN
# 11683   4467_119      NaN
#
# [11684 rows x 2 columns]

# %%
data[['id_num','is_pass']]
# Out:
#           id_num  is_pass
# 0       1442_124      NaN
# 1       12373_38      NaN
# 2       12035_21      NaN
# 3       11148_86      NaN
# 4       1362_131      NaN
# ...          ...      ...
# 11679   3882_161      NaN
# 11680    3426_38      NaN
# 11681  13063_142      NaN
# 11682    5667_82      NaN
# 11683   4467_119      NaN
#
# [11684 rows x 2 columns]

# %%
new['is_pass'] = 1

# %%
new
# Out:
#           id_num  is_pass
# 0       1442_124        1
# 1       12373_38        1
# 2       12035_21        1
# 3       11148_86        1
# 4       1362_131        1
# ...          ...      ...
# 11679   3882_161        1
# 11680    3426_38        1
# 11681  13063_142        1
# 11682    5667_82        1
# 11683   4467_119        1
#
# [11684 rows x 2 columns]

# %%
new.to_csv('allone.csv')

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11684 entries, 0 to 11683
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_num   11684 non-null  object
#  1   is_pass  11684 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 182.7+ KB

# %%
re = pd.read_csv('allone.csv')

# %%
re
# Out:
#        Unnamed: 0     id_num  is_pass
# 0               0   1442_124        1
# 1               1   12373_38        1
# 2               2   12035_21        1
# 3               3   11148_86        1
# 4               4   1362_131        1
# ...           ...        ...      ...
# 11679       11679   3882_161        1
# 11680       11680    3426_38        1
# 11681       11681  13063_142        1
# 11682       11682    5667_82        1
# 11683       11683   4467_119        1
#
# [11684 rows x 3 columns]

# %%
after = re.drop('Unnamed: 0', axis=1)
after
# Out:
#           id_num  is_pass
# 0       1442_124        1
# 1       12373_38        1
# 2       12035_21        1
# 3       11148_86        1
# 4       1362_131        1
# ...          ...      ...
# 11679   3882_161        1
# 11680    3426_38        1
# 11681  13063_142        1
# 11682    5667_82        1
# 11683   4467_119        1
#
# [11684 rows x 2 columns]

# %%
after.to_csv('after.csv')

# %%
re.to_csv('again.csv', index=False)
